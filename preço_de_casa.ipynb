# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-kopke-jr/Projects_entrevistas_portfolio/blob/main/pre%C3%A7o_de_casa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
teste = pd.read_csv('test.csv')
treino = pd.read_csv('train.csv')
dados = pd.concat([treino,teste])
dados.drop('Id',axis = 'columns',inplace = True)

# %%
colunas = list(treino.columns)

# %%
colunas_dc = {
    'MSSubClass':'Tipo_de_habitação',
    'MSZoning':'Classificação zoneamento',
    'LotFrontage' : 'Distancia da casa a rua',
    'LotArea' : 'Area do lote',
    'Street': 'Tipo de pavimentação',
    'Alley' : 'Tipo de acesso a propriedade',
    'LotShape' : 'Formato do lote',
    'LandContour': 'Planicidade de imovel',
    'Utilities': 'Utilidades disponiveis',
    'LotConfig': 'Configuração do lote',
    'LandSlope': 'Inclinação do terreno',
    'Neighborhood': 'Vizinhança',
    'Condition1': 'Caracteristicas 1',
    'Condition2': 'Caracteristicas 2',
    'BldgType': 'Tipo de habitação',
    'HouseStyle': 'Estilo de casa',
    'OverallQual': 'Qualidade do imovel',
    'OverallCond': 'Condicao geral do imovel',
    'YearBuilt': 'Ano de construcao',
    'YearRemodAdd': 'Ano de reformas',
    'RoofStyle': 'Tipo de telhado',
    'RoofMatl': 'Material do telhado',
    'Exterior1st': 'material cobertura exterior 1',
    'Exterior2nd': 'Material cobertura exterior 2',
    'MasVnrType': 'tipo de folheado de alvenaria',
    'MasVnrArea': 'Alvenaria polegada quadrada',
    'ExterQual': 'Qualidade externa',
    'ExterCond':'Condicao externa',
    'Foundation': 'Tipo de fundação',
    'BsmtQual': 'Altura do porão',
    'BsmtCond': 'Condicao geral do porao',
    'BsmtExposure': 'Paredes do jardim',
    'BsmtFinType1':'Qualidade acabamento',
    'BsmtFinSF1': 'Area acabada 1',
    'BsmtFinType2': 'Qualidade acabamento 2',
    'BsmtFinSF2': 'Area acabada 2',
    'BsmtUnfSF': 'Area nao acabada',
    'TotalBsmtSF': 'area de acabamento total',
    'Heating':'Tipo de aquecimento',
    'HeatingQC':'Qualidade de aquecimento',
    'CentralAir':'Condicionamento central',
    'Electrical': 'Sistema eletrico',
    '1stFlrSF': 'Area do primeiro andar',
    '2ndFlrSF': 'Area do segundo andar',
    'LowQualFinSF': 'Area acabada com baixa qualidade',
    'GrLivArea': ''




 

}

# %%
for coluna in colunas:
  sns.scatterplot(x = coluna,y = 'SalePrice',data = treino)
  plt.title('Variação do preço de venda com {}'.format(coluna),fontsize = 16)
  plt.xlabel("Preço de venda",fontsize = 14)
  plt.ylabel(coluna,fontsize = 14)
  plt.show()
  print('---------', coluna)
# Out:
# --------- Id
# --------- MSSubClass
# --------- MSZoning
# --------- LotFrontage
# --------- LotArea
# --------- Street
# --------- Alley
# --------- LotShape
# --------- LandContour
# --------- Utilities
# --------- LotConfig
# --------- LandSlope
# --------- Neighborhood
# --------- Condition1
# --------- Condition2
# --------- BldgType
# --------- HouseStyle
# --------- OverallQual
# --------- OverallCond
# --------- YearBuilt
# --------- YearRemodAdd
# --------- RoofStyle
# --------- RoofMatl
# --------- Exterior1st
# --------- Exterior2nd
# --------- MasVnrType
# --------- MasVnrArea
# --------- ExterQual
# --------- ExterCond
# --------- Foundation
# --------- BsmtQual
# --------- BsmtCond
# --------- BsmtExposure
# --------- BsmtFinType1
# --------- BsmtFinSF1
# --------- BsmtFinType2
# --------- BsmtFinSF2
# --------- BsmtUnfSF
# --------- TotalBsmtSF
# --------- Heating
# --------- HeatingQC
# --------- CentralAir
# --------- Electrical
# --------- 1stFlrSF
# ...

# %%
colunas

# %%
for coluna in colunas:
  sns.boxplot(x = coluna,y = 'SalePrice',data = treino)
  plt.title('Variação do preço de venda com {}'.format(coluna),fontsize = 16)
  plt.xlabel("Preço de venda",fontsize = 14)
  plt.ylabel(coluna,fontsize = 14)
  plt.show()

# %%
candidatos = ['MSZoning','Alley','OverallQual','ExterQual','BsmtQual','CentralAir','FullBath','KitchenQual','TotalBsmtSF',
 'GarageArea', 'LotArea','Street','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageYrBlt']

# %%
len(candidatos)
# Out:
# 19

# %%
for candidato in candidatos:
  if candidato in ['TotalBsmtSF','GarageArea','GarageArea','YearBuilt','YearRemodAdd','LotArea','1stFlrSF','2ndFlrSF','GrLivArea','GarageYrBlt']:
    print('--------------\n')
    print(candidato)
    sns.scatterplot(x = candidato ,y = 'SalePrice',data = treino)
    plt.title('Variação do preço de venda com {}'.format(candidato),fontsize = 16)
    plt.xlabel("Preço de venda",fontsize = 14)
    plt.ylabel(candidato,fontsize = 14)
    plt.show()
    print('---------', candidato)
  else:
    print('--------------\n')
    print(candidato)
    sns.boxplot(x = candidato,y = 'SalePrice',data = treino)
    plt.title('Variação do preço de venda com {}'.format(candidato),fontsize = 16)
    plt.xlabel("Preço de venda",fontsize = 14)
    plt.ylabel(candidato,fontsize = 14)
    plt.show()
# Out:
# --------------
#
# MSZoning
# --------------
#
# Alley
# --------------
#
# OverallQual
# --------------
#
# ExterQual
# --------------
#
# BsmtQual
# --------------
#
# CentralAir
# --------------
#
# FullBath
# --------------
#
# KitchenQual
# --------------
#
# TotalBsmtSF
# --------- TotalBsmtSF
# --------------
#
# GarageArea
# --------- GarageArea
# --------------
#
# LotArea
# --------- LotArea
# --------------
#
# Street
# --------------
#
# YearBuilt
# --------- YearBuilt
# --------------
#
# YearRemodAdd
# --------- YearRemodAdd
# --------------
#
# TotalBsmtSF
# --------- TotalBsmtSF
# --------------
#
# 1stFlrSF
# --------- 1stFlrSF
# --------------
#
# 2ndFlrSF
# --------- 2ndFlrSF
# --------------
#
# GrLivArea
# --------- GrLivArea
# --------------
#
# GarageYrBlt
# --------- GarageYrBlt

# %%
candidatos.remove('Street')
candidatos.remove('LotArea')
